# %%
# Question 1: Load
# Programmatically download and load into your favorite analytical tool the transactions data. This data, which is in line-delimited JSON format, can be found here

# Please describe the structure of the data. Number of records and fields in each record?

# Please provide some additional basic summary statistics for each field. Be sure to include a count of null, minimum, maximum, and unique values where appropriate.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Question 1-1: download and load the dataset

# %%
#importing the required libraries
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#supress warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.read_json('/dbfs/FileStore/shared_uploads/folder.com/transactions.txt', lines=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#get the dataframe dimension  
print(df.shape)
#head of the dataframe
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(786363, 29)
# Out[63]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accountNumber</th>
#       <th>customerId</th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionDateTime</th>
#       <th>transactionAmount</th>
#       <th>merchantName</th>
# ...

# %%
#tail of the dataframe
df.tail()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accountNumber</th>
#       <th>customerId</th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionDateTime</th>
#       <th>transactionAmount</th>
#       <th>merchantName</th>
#       <th>acqCountry</th>
# ...

# %%
# dataframe columns
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[65]: Index([&#39;accountNumber&#39;, &#39;customerId&#39;, &#39;creditLimit&#39;, &#39;availableMoney&#39;,
#        &#39;transactionDateTime&#39;, &#39;transactionAmount&#39;, &#39;merchantName&#39;,
#        &#39;acqCountry&#39;, &#39;merchantCountryCode&#39;, &#39;posEntryMode&#39;, &#39;posConditionCode&#39;,
#        &#39;merchantCategoryCode&#39;, &#39;currentExpDate&#39;, &#39;accountOpenDate&#39;,
#        &#39;dateOfLastAddressChange&#39;, &#39;cardCVV&#39;, &#39;enteredCVV&#39;, &#39;cardLast4Digits&#39;,
#        &#39;transactionType&#39;, &#39;echoBuffer&#39;, &#39;currentBalance&#39;, &#39;merchantCity&#39;,
# ...

# %% [markdown]
# ### Question 1-2: describe the structure of the data, Number of records and fields

# %%
# dataframe shape or dimention 
print(df.shape)
number_of_rows = df.shape[0] 
number_of_columns = df.shape[1] 
print("Number of rows:", number_of_rows, ", Number of columns:", number_of_columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(786363, 29)
# Number of rows: 786363 , Number of columns: 29
# </div>

# %% [markdown]
# ###### Number of records (rows) 786,363
# ###### Number of fields (columns) 29

# %%
#basic info about the dataframe like type of variables
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  int64
#  1   customerId                786363 non-null  int64
#  2   creditLimit               786363 non-null  int64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   merchantName              786363 non-null  object
# ...

# %% [markdown]
# ### Question 1-3: additional basic summary statistics for each field

# %%
# Please provide some additional basic summary statistics for each field. Be sure to include a count of null, minimum, maximum, and unique values where appropriate.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### let's look at the number of null values for each column

# %%
#The count of individual columns count of null values
print(df.isnull().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">accountNumber               0
# customerId                  0
# creditLimit                 0
# availableMoney              0
# transactionDateTime         0
# transactionAmount           0
# merchantName                0
# acqCountry                  0
# merchantCountryCode         0
# posEntryMode                0
# posConditionCode            0
# merchantCategoryCode        0
# currentExpDate              0
# accountOpenDate             0
# dateOfLastAddressChange     0
# cardCVV                     0
# enteredCVV                  0
# cardLast4Digits             0
# transactionType             0
# echoBuffer                  0
# ...

# %%
#sort the variables (columns) based on their number of missing values
import pandas as pd

null_counts = df.isnull().sum()
null_counts[null_counts > 0].sort_values(ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[70]: Series([], dtype: int64)</div>

# %%
#The total null values present in the df
print("Total Null values count: ",
      df.isnull().sum().sum())
null_columns=df.columns[df.isnull().any()]
print(null_columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total Null values count:  0
# Index([], dtype=&#39;object&#39;)
# </div>

# %%
print('the following variabes are all empty, so we should drop them later')
print(df['posOnPremises'].value_counts())
print(df['merchantCity'].value_counts())
print(df['merchantZip'].value_counts())
print(df['recurringAuthInd'].value_counts())
print(df['echoBuffer'].value_counts())
print(df['merchantState'].value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">the following variabes are all empty, so we should drop them later
#     786363
# Name: posOnPremises, dtype: int64
#     786363
# Name: merchantCity, dtype: int64
#     786363
# Name: merchantZip, dtype: int64
#     786363
# Name: recurringAuthInd, dtype: int64
#     786363
# Name: echoBuffer, dtype: int64
#     786363
# Name: merchantState, dtype: int64
# </div>

# %% [markdown]
# ##### Conclusion: the following variabes are all empty, so we should drop them later:
# ##### 'posOnPremises', 'merchantCity', 'merchantZip', 'recurringAuthInd', 'echoBuffer', 'merchantState'

# %%
#check the min and max of numeric variables
print("max of credit limit is:" , df['creditLimit'].max())
print("min of credit limit is:" , df['creditLimit'].min())

print("max of Available Money is:" , df['availableMoney'].max())
print("min of Available Money:" , df['availableMoney'].min())

print("max of Transaction Amount is:" , df['transactionAmount'].max())
print("min of Transaction Amount:" , df['transactionAmount'].min())


print("max of Available Money is:" , df['currentBalance'].max())
print("min of Available Money:" , df['currentBalance'].min())

print("max of Available Money is:" , df['cardPresent'].max())
print("min of Available Money:" , df['cardPresent'].min())

print("max of Available Money is:" , df['expirationDateKeyInMatch'].max())
print("min of Available Money:" , df['expirationDateKeyInMatch'].min())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">max of credit limit is: 50000
# min of credit limit is: 250
# max of Available Money is: 50000.0
# min of Available Money: -1005.63
# max of Transaction Amount is: 2011.54
# min of Transaction Amount: 0.0
# max of Available Money is: 47498.81
# min of Available Money: 0.0
# max of Available Money is: True
# min of Available Money: False
# max of Available Money is: True
# min of Available Money: False
# </div>

# %%
#check number of unique values for categorical features
print('number of levels or unique values for merchant category code:' , df['merchantCategoryCode'].nunique())
print('number of levels or unique values for merchant Country Code:' , df['merchantCountryCode'].nunique())
print('number of levels or unique values for acq Country code:' , df['acqCountry'].nunique())
print('number of levels or unique values for pos Entry Mode:' , df['posEntryMode'].nunique())
print('number of levels or unique values for pos Condition Code:' , df['posConditionCode'].nunique())
print('number of levels or unique values for transaction Type:' , df['transactionType'].nunique())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of levels or unique values for merchant category code: 19
# number of levels or unique values for merchant Country Code: 5
# number of levels or unique values for acq Country code: 5
# number of levels or unique values for pos Entry Mode: 6
# number of levels or unique values for pos Condition Code: 4
# number of levels or unique values for transaction Type: 4
# </div>

# %%
#check number of distribusion of boolean features
print('number of unique values for each level of card Present:\n' , df['cardPresent'].value_counts())
print('number of unique values for each level of expiration DateKey In Match:\n' , df['expirationDateKeyInMatch'].value_counts())
print('number of unique values for each level of is Fraudt:\n' , df['isFraud'].value_counts())

print("rate of False class - card Present is\n", round(df['cardPresent'].value_counts(normalize=True)[1], 7))
print("rate of True class - is card Present is\n", round(df['cardPresent'].value_counts(normalize=True)[0], 7))

print("rate of minor(False) class - expiration DateKey In Match is\n", round(df['expirationDateKeyInMatch'].value_counts(normalize=True)[1], 7))
print("rate of major(True) class - is expiration DateKey In Match is\n", round(df['expirationDateKeyInMatch'].value_counts(normalize=True)[0], 7))

print("rate of minor(True) class - isFraud is\n", round(df['isFraud'].value_counts(normalize=True)[1], 7))
print("rate of major(False) class - is not Fraud is\n", round(df['isFraud'].value_counts(normalize=True)[0], 7))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of unique values for each level of card Present:
#  False    433495
# True     352868
# Name: cardPresent, dtype: int64
# number of unique values for each level of expiration DateKey In Match:
#  False    785320
# True       1043
# Name: expirationDateKeyInMatch, dtype: int64
# number of unique values for each level of is Fraudt:
#  False    773946
# True      12417
# Name: isFraud, dtype: int64
# rate of False class - card Present is
#  0.4487342
# rate of True class - is card Present is
#  0.5512658
# rate of minor(False) class - expiration DateKey In Match is
#  0.0013264
# ...

# %% [markdown]
# ##### Conclusion: variables 'expirationDateKeyInMatch' and 'isFraud' are not following a normal distributon and are highly skewed toward right

# %% [markdown]
# ### Question 2-1: histogram plot of the transactionAmount column.

# %%
# Plot a histogram of the processed amounts of each transaction, the transactionAmount column.
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(df['transactionAmount'], bins=30);
plt.xlabel('Transaction Amount');

# %% [markdown]
# ##### Conclusion: variable 'transactionAmount' is not following a normal distributon and are highly skewed toward right

# %%
# Question 2: Plot
# Plot a histogram of the processed amounts of each transaction, the transactionAmount column.
# Report any structure you find and any hypotheses you have about that structure.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Question 2-2: structure and hypotheses test

# %% [markdown]
# ##### Let's test a few hypothesis as follows:
# 1) Variables 'expirationDateKeyInMatch', 'transactionAmount' and 'isFraud' do not follow a normal distribution and are highly skewed towards right.
#
# 2) There is a relationship or Statistical significance between variables creditLimit', 'transactionType' and 'sameCVV' which is a new variable with variable 'isFraud'
#
# 3) Checking the distribution of numerical variables creditLimit', 'availableMoney',transactionAmount', and 'currentBalance'
#
# 4) Another intresting structure to find out about the data is to explore to find out which accounts have more number of frauds and which merchants mostly they purchase from

# %% [markdown]
# ##### Testing the hyothesis that a few variables are not following a normal distribution, c and statistically

# %%
# D'Agostino and Pearson's Test for 'expirationDateKeyInMatch'
from numpy.random import seed
from numpy.random import randn
from scipy.stats import normaltest
# seed the random number generator
seed(1)
# normality test
stat, p = normaltest(df['expirationDateKeyInMatch'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('expirationDateKeyInMatch looks Gaussian (fail to reject H0)')
else:
	print('variable expirationDateKeyInMatch does not look Gaussian (reject H0)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Statistics=1951280.777, p=0.000
# variable expirationDateKeyInMatch does not look Gaussian (reject H0)
# </div>

# %%
#visually
import seaborn as sns
noMatch_transactions = df['expirationDateKeyInMatch'].value_counts()

sns.barplot(x=[0,1], y=noMatch_transactions)
plt.xticks(ticks=[0,1], labels=['False', 'True'])
plt.ylabel('Count')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[79]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0, 0.5, &#39;Count&#39;)</div>

# %%
# D'Agostino and Pearson's Test for 'transactionAmount'
from numpy.random import seed
from numpy.random import randn
from scipy.stats import normaltest
# seed the random number generator
seed(1)
# normality test
stat, p = normaltest(df['transactionAmount'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('transactionAmount looks Gaussian (fail to reject H0)')
else:
	print('variable transactionAmount does not look Gaussian (reject H0)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Statistics=347341.847, p=0.000
# variable transactionAmount does not look Gaussian (reject H0)
# </div>

# %%
# visually
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.hist(df['transactionAmount'], bins=30);
plt.xlabel('Transaction Amount');

# %%
# D'Agostino and Pearson's Test for 'isFraud'
from numpy.random import seed
from numpy.random import randn
from scipy.stats import normaltest
# seed the random number generator
seed(1)
# normality test
stat, p = normaltest(df['isFraud'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('isFraud looks Gaussian (fail to reject H0)')
else:
	print('variable isFraud does not look Gaussian (reject H0)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Statistics=1030266.215, p=0.000
# variable isFraud does not look Gaussian (reject H0)
# </div>

# %%
#visually
import seaborn as sns
fraud_transactions = df['isFraud'].value_counts()

sns.barplot(x=[0,1], y=fraud_transactions)
plt.xticks(ticks=[0,1], labels=['False', 'True'])
plt.ylabel('Count')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0, 0.5, &#39;Count&#39;)</div>

# %% [markdown]
# ##### Conclusion: The hypothesis is confirmed that variables 'expirationDateKeyInMatch', 'transactionAmount' and 'isFraud do not follow a normal distributon and are highly skewed toward right

# %% [markdown]
# ##### Testing the hyothesis of singnificance relationship among a few variables

# %%
#to determine if there is significant deference between means of two variables 'isFraud' with following variables: 'creditLimit', 'transactionType'
import numpy as np
from scipy.stats import ttest_ind

v1 = df['isFraud']
v2 = df['creditLimit']
v3 = df['cardPresent']
res = ttest_ind(v1, v2)
print('significance test for creditlimit:', ttest_ind(v1, v2))
print('significance test for transactionType:', ttest_ind(v1, v3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">significance test for creditlimit: Ttest_indResult(statistic=-819.9574446757522, pvalue=0.0)
# significance test for transactionType: Ttest_indResult(statistic=-748.7500312324491, pvalue=0.0)
# </div>

# %%
import seaborn as sns
sns.countplot(data=df, x='creditLimit', hue='isFraud')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:xlabel=&#39;creditLimit&#39;, ylabel=&#39;count&#39;&gt;</div>

# %%
import seaborn as sns
sns.countplot(data=df, x='cardPresent', hue='isFraud')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:xlabel=&#39;cardPresent&#39;, ylabel=&#39;count&#39;&gt;</div>

# %%
import seaborn as sns
sns.countplot(data=df, x='posConditionCode', hue='isFraud')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:xlabel=&#39;posConditionCode&#39;, ylabel=&#39;count&#39;&gt;</div>

# %%
sns.countplot(data=df, x='posEntryMode', hue='isFraud')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:xlabel=&#39;posEntryMode&#39;, ylabel=&#39;count&#39;&gt;</div>

# %%
# Set up a grid of plots
fig = plt.figure(figsize=(12,12)) 
fig_dims = (3, 2)


# Plot accidents depending on type
plt.subplot2grid(fig_dims, (0, 0))
df['cardPresent'].value_counts().plot(kind='bar', 
                                     title='card Present')
plt.subplot2grid(fig_dims, (0, 1))
df['posOnPremises'].value_counts().plot(kind='bar', color = 'pink',
                                     title='pos On Premises')
plt.subplot2grid(fig_dims, (1, 0))
df['expirationDateKeyInMatch'].value_counts().plot(kind='bar', color = 'orange',
                                     title='expiration Date Key In Match')
plt.subplot2grid(fig_dims, (1, 1))
df['isFraud'].value_counts().plot(kind='bar', color = 'green',
                                     title='is Fraud')
# plt.subplot2grid(fig_dims, (1, 0))
# df['recurringAuthInd'].value_counts().plot(kind='bar', color = 'red',
#                                      title='recurring Auth Ind')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[89]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:title={&#39;center&#39;:&#39;is Fraud&#39;}&gt;</div>

# %%
sns.countplot(data=df, x='isFraud', hue='cardPresent')
plt.xlabel('Is Fraud')
plt.ylabel('Amount of Transactions')
plt.title('Relationship between Card Present Transactions and Fraudulent Transactions')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[90]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 1.0, &#39;Relationship between Card Present Transactions and Fraudulent Transactions&#39;)</div>

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
stat, p, dof, expected = chi2_contingency(df[['creditLimit','isFraud']])
p
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[91]: 0.0</div>

# %%
import scikit_posthocs as sp
sp.posthoc_ttest(df, val_col='creditLimit', group_col='isFraud', p_adjust='holm')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>False</th>
#       <th>True</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>1.000000</td>
#       <td>0.005854</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>0.005854</td>
# ...

# %%
import statsmodels.api as sa
import statsmodels.formula.api as sfa
lm = sfa.ols('creditLimit ~ C(isFraud)', data=df).fit()
anova = sa.stats.anova_lm(lm)
print(anova)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                  df        sum_sq       mean_sq         F    PR(&gt;F)
# C(isFraud)       1.0  1.028308e+09  1.028308e+09  7.594627  0.005854
# Residual    786361.0  1.064728e+14  1.353994e+08       NaN       NaN
# </div>

# %%
df['sameCVV'] = df['cardCVV'] == df['enteredCVV']

ax = sns.countplot(data=df, x='sameCVV', hue='isFraud')
for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 6700
            value = p.get_height()
            ax.text(_x, _y, value, ha="center", fontsize=14)
plt.xlabel('same CVV')

v4 = df['sameCVV']
print('significance test for creditlimit:', ttest_ind(v1, v4))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">significance test for creditlimit: Ttest_indResult(statistic=-5538.689340786272, pvalue=0.0)
# </div>

# %%
print('percentage of fraud transactions is:', round(12417 /(12417 +773946), 5), 'while percentage of not fraud transactions is:', round(773946 /(12417 +773946),5))
df['isFraud'].value_counts().plot.bar(rot=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">percentage of fraud transactions is: 0.01579 while percentage of not fraud transactions is: 0.98421
# Out[95]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;AxesSubplot:&gt;</div>

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20,15))

numerical_features = ['creditLimit', 'availableMoney', 'transactionAmount', 'currentBalance']
numerical_features_titles = ['Credit Limit', 'Available Money', 'Transaction Amount', 'Current Balance']
colors = ['#3C91E6', '#9BE564', '#0D3B66', '#59C9A5']
counter = 0

for i in range(2):
    for j in range(2):
        sns.distplot(df[numerical_features[counter]], ax=ax[i][j], color=colors[counter])
        ax[i][j].set_xlabel(numerical_features_titles[counter], fontsize=20)
        ax[i][j].set_ylabel('')
        counter+=1

fig.suptitle('Numerical Features Distribution', fontsize=22)
fig.subplots_adjust(top=0.95)

# %%
fraud_transactions_only = df[df['isFraud'] == True]

top10_fraudulent_accounts = fraud_transactions_only['accountNumber'].value_counts().head(10)
sns.barplot(y=list(range(10)), x=top10_fraudulent_accounts.values, orient='v')

plt.yticks(ticks=list(range(10)), labels=top10_fraudulent_accounts.index.tolist())
plt.ylabel('Account Number')
plt.xlabel('Fraudulent Transactions')
plt.title('Top 10 Accounts with the Most Fraudulent Transactions')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 1.0, &#39;Top 10 Accounts with the Most Fraudulent Transactions&#39;)</div>

# %%
largest_fraud = top10_fraudulent_accounts.index[0]
largest_fraud_data = df[(df['accountNumber'] == largest_fraud) & (df['isFraud'] == True)]
largest_fraud_top_merchants = largest_fraud_data['merchantName'].value_counts()

ax = sns.barplot(y=list(range(len(largest_fraud_top_merchants))), x=largest_fraud_top_merchants.values, orient='v')
for p in ax.patches:
    width = p.get_width()
    ax.text(width+9.5  ,
        p.get_y()+p.get_height()/2. + 0.2,
        int(width),
        ha="center", fontsize=12)

plt.yticks(ticks=list(range(len(largest_fraud_top_merchants))), labels=largest_fraud_top_merchants.index.tolist())
plt.xlabel('Amount of Transactions')
plt.ylabel('Merchant')
plt.title('Most Popular Merchants of Account 380680241')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[98]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 1.0, &#39;Most Popular Merchants of Account 380680241&#39;)</div>

# %% [markdown]
# #### Conclusions:
# 1) Since p-value for all the normality and significance tests where 0.0 which is lower than alpha (0.05) level, the null hypothesis are rejected and therefore:
# Variables 'expirationDateKeyInMatch', 'transactionAmount' and 'isFraud' do not follow a normal distribution and are highly skewed towards right.
#
# 2) There is a relationship or Statistical significance between variables creditLimit', 'transactionType' and 'sameCVV' which is a new variable with variable 'isFraud'
#
# 3) 'sameCVV' is a new variable that is formed based on the actual CVV on the card and what is entered. Because of their significance difference, we can conclude that these variables have a predictive power to predict the fraudulant transactions.
#
# 4) One important structure of the data is how it is imbalanced toward 'True' vs. 'False' class. Percentage of fraud transactions is: 0.01579 while percentage of not fraud transactions is: 0.98421. The data is highly skewed toward class True and the histogram plot looks like a lopsided mound, with a tail going off to the right.
#
# 5) Looking at the distribution plot of the varaible 'creditLimit', we find out that the distribution is multimodal and in order to discover the pattern, looking at only one simple transformation is not enough.
# Distribution plot of the varaible 'availableMoney' shows that it is extremely right skewed which is not hard to guess because available money is is usually less than credit limit.
# Looking at the distribution plots of varaible 'transactionAmount' as mentioned before and variable 'currentBalance', are right skewed.
#
# 6) Account 380680241 has the largest fraud, from merchants Fresh Flowers and Blue Mountain Online Services.

# %% [markdown]
# ### Question 3

# %%
# Question 3: Data Wrangling - Duplicate Transactions
# You will notice a number of what look like duplicated transactions in the data set. One type of duplicated transaction is a reversed transaction, where a purchase is followed by a reversal. Another example is a multi-swipe, where a vendor accidentally charges a customer's card multiple times within a short time span.

# Can you programmatically identify reversed and multi-swipe transactions?

# What total number of transactions and total dollar amount do you estimate for the reversed transactions? For the multi-swipe transactions? (please consider the first transaction to be "normal" and exclude it from the number of transaction and dollar amount counts)

# Did you find anything interesting about either kind of transaction?
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Question 3-1: identify reversed and multi-swipe transactions?

# %%
#variable sameCVV is created in the previous section to identify whether the enteredCVV is same as cardCVV
df['sameCVV'] = df['cardCVV'] == df['enteredCVV']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#variable followedReversal is created to identify purchases that were followed with a reversal
df['followedReversal'] = np.where(df['transactionType'] == 'REVERSAL', 1, 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
df['followedReversal'] = np.where(df['transactionType'] == 'REVERSAL', 1, 0)
df['followedReversal'].value_counts()
ax = sns.countplot(data=df, x='followedReversal', hue='isFraud')
for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 6700
            value = p.get_height()
            ax.text(_x, _y, value, ha="center", fontsize=14)
plt.xlabel('followed Reversal')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 0, &#39;followed Reversal&#39;)</div>

# %%
df['transactionDateTime'] = pd.to_datetime(df['transactionDateTime'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#change the format of transactionDateTime
df['transactionDateTime'] = pd.to_datetime(df['transactionDateTime'])

#variable multiSwipe is created based on the transactionDateTime and transactionAmount to identify whether customer has swiped the card more than once
df['multiSwipe'] = (df.sort_values(['transactionDateTime'])
                       .groupby(['customerId', 'transactionAmount'], sort=False)['transactionDateTime']
                       .diff()
                       .dt.total_seconds()
                       .lt(120))
ax = sns.countplot(data=df, x='multiSwipe', hue='isFraud')
for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 6700
            value = p.get_height()
            ax.text(_x, _y, value, ha="center", fontsize=14)
plt.xlabel('multi Swipe')
df['multiSwipe'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[104]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">False    777481
# True       8882
# Name: multiSwipe, dtype: int64</div>

# %%
#variable duplicated is created to identify whether the ransaction was foloowed by a reversal OR the card was swiped multiple times
df['duplicated']  = np.where(
   (df.followedReversal == 1) | (df.multiSwipe == 'True'), 1,0)

ax = sns.countplot(data=df, x='duplicated', hue='isFraud')
for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 6700
            value = p.get_height()
            ax.text(_x, _y, value, ha="center", fontsize=14)
plt.xlabel('duplicated')
df['duplicated'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[105]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0    766060
# 1     20303
# Name: duplicated, dtype: int64</div>

# %% [markdown]
# ##### Conclusions:
# Three new variables are created and

# %% [markdown]
# ### Question 3-2: total number of transactions and total dollar amount do you estimate for the reversed and multi-swipe transactions

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[106]: Index([&#39;accountNumber&#39;, &#39;customerId&#39;, &#39;creditLimit&#39;, &#39;availableMoney&#39;,
#        &#39;transactionDateTime&#39;, &#39;transactionAmount&#39;, &#39;merchantName&#39;,
#        &#39;acqCountry&#39;, &#39;merchantCountryCode&#39;, &#39;posEntryMode&#39;, &#39;posConditionCode&#39;,
#        &#39;merchantCategoryCode&#39;, &#39;currentExpDate&#39;, &#39;accountOpenDate&#39;,
#        &#39;dateOfLastAddressChange&#39;, &#39;cardCVV&#39;, &#39;enteredCVV&#39;, &#39;cardLast4Digits&#39;,
#        &#39;transactionType&#39;, &#39;echoBuffer&#39;, &#39;currentBalance&#39;, &#39;merchantCity&#39;,
# ...

# %%
#followedReversal analysis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.groupby('followedReversal', as_index=False)['transactionAmount'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[108]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>followedReversal</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1.048988e+08</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
# ...

# %%
#first let's get the number of transactions and average and total dollar amount for purchases that were and were not followed by a reversal without excluding the normal transactions
print('total transaction Amount for reversed and non reversal purchases are:', df.groupby('followedReversal', as_index=False)['transactionAmount'].sum())
print('average transaction Amount for reversed and non reversal purchases are:', df.groupby('followedReversal', as_index=False)['transactionAmount'].mean())
print('number of transactions for reversed and non reversal purchases are:', df.groupby('followedReversal', as_index=False)['transactionAmount'].count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total transaction Amount for reversed and non reversal purchases are:    followedReversal  transactionAmount
# 0                 0       1.048988e+08
# 1                 1       2.821792e+06
# average transaction Amount for reversed and non reversal purchases are:    followedReversal  transactionAmount
# 0                 0         136.932832
# 1                 1         138.984017
# number of transactions for reversed and non reversal purchases are:    followedReversal  transactionAmount
# 0                 0             766060
# 1                 1              20303
# </div>

# %%
#now let's remove the normal transacation and get the number of transactions and average and total transaction amounts where the purchase was folowed by a reversal
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#first we define a dataframe for purchases followed by reversals
df_followedReversal= df[['customerId', 'followedReversal', 'transactionAmount']]
df_followedReversal= df_followedReversal[df_followedReversal['followedReversal'] != False]
df_followedReversal.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customerId</th>
#       <th>followedReversal</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>39</th>
#       <td>574788567</td>
#       <td>1</td>
#       <td>215.13</td>
#     </tr>
# ...

# %%
#which ones are the normal transations for purchases followed by reversals
df_followedReversal.groupby('customerId', as_index=False).nth(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[112]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customerId</th>
#       <th>followedReversal</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>39</th>
#       <td>574788567</td>
#       <td>1</td>
#       <td>215.13</td>
#     </tr>
# ...

# %%
#then let's remove the normal transcations which are the first transaction of each customerId
def using_nth(df):
    to_del = df.groupby('customerId',as_index=False).nth(0)
    return pd.concat([df,to_del]).drop_duplicates(keep=False)
  
df_followedReversal_removed_normal = using_nth(df_followedReversal)
df_followedReversal_removed_normal['transactionAmount'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[113]: 2395462.5100000002</div>

# %%
#after removing the normal transactions, we get the number of transactions, average and total transaction for purchases followed by reversals
print('number of transactions for purchases followed by reversals after excluding the normal ones is:', df_followedReversal_removed_normal['transactionAmount'].count())
print('average transaction amount for purchases followed by reversals after excluding the normal ones is:', df_followedReversal_removed_normal['transactionAmount'].mean())
print('total transaction amount for purchases followed by reversals after excluding the normal ones is:', df_followedReversal_removed_normal['transactionAmount'].sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of transactions for purchases followed by reversals after excluding the normal ones is: 16938
# average transaction amount for purchases followed by reversals after excluding the normal ones is: 141.4253459676458
# total transaction amount for purchases followed by reversals after excluding the normal ones is: 2395462.5100000002
# </div>

# %%
#multiSwipe analysis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.groupby('multiSwipe', as_index=False)['transactionAmount'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[116]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>multiSwipe</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>1.064162e+08</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
# ...

# %%
#first let's get the number of transactions and average and total dollar amount for purchases that the merchant did or did not swipe multiple times were without excluding the normal transactions
print('total transaction Amount for multi Swipe transactions are:', df.groupby('multiSwipe', as_index=False)['transactionAmount'].sum())
print('average transaction Amount for multi Swipe purchases are:', df.groupby('multiSwipe', as_index=False)['transactionAmount'].mean())
print('number of transactions for multi Swipe transactions are:', df.groupby('multiSwipe', as_index=False)['transactionAmount'].count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total transaction Amount for multi Swipe transactions are:    multiSwipe  transactionAmount
# 0       False       1.064162e+08
# 1        True       1.304345e+06
# average transaction Amount for multi Swipe purchases are:    multiSwipe  transactionAmount
# 0       False         136.873071
# 1        True         146.852669
# number of transactions for multi Swipe transactions are:    multiSwipe  transactionAmount
# 0       False             777481
# 1        True               8882
# </div>

# %%
#now let's remove the normal transacation and get the number of transactions and average and total transaction amounts where theere are multiple swipes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#first we define a dataframe for multiple swipes
df_multiSwipe = df[['customerId', 'multiSwipe', 'transactionAmount']]
df_multiSwipe= df_multiSwipe[df_multiSwipe['multiSwipe'] != False]
df_multiSwipe
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[119]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customerId</th>
#       <th>multiSwipe</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>133</th>
#       <td>984504651</td>
#       <td>True</td>
#       <td>450.74</td>
#     </tr>
#     <tr>
# ...

# %%
#which ones are the normal transations for multiSwipe?
df_multiSwipe.groupby('customerId', as_index=False).nth(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[120]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customerId</th>
#       <th>multiSwipe</th>
#       <th>transactionAmount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>133</th>
#       <td>984504651</td>
#       <td>True</td>
#       <td>450.74</td>
#     </tr>
#     <tr>
# ...

# %%
#then let's remove the normal transcations which are the first transaction of each customerId
def using_nth(df):
    to_del = df.groupby('customerId',as_index=False).nth(0)
    return pd.concat([df,to_del]).drop_duplicates(keep=False)
  
df_multiSwipe_removed_normal = using_nth(df_multiSwipe)
df_multiSwipe_removed_normal['transactionAmount'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[121]: 881816.45</div>

# %%
#after removing the normal transactions, we get the number of transactions, average and total transaction amount for multiSwipe transactions
print('number of transactions for multi Swipe transactions after excluding the normal ones is:', df_multiSwipe_removed_normal['transactionAmount'].count())
print('average transaction amount for multi Swipe transactions after excluding the normal ones is:', df_multiSwipe_removed_normal['transactionAmount'].mean())
print('total transaction amount for multi Swipe transactions after excluding the normal ones is:',df_multiSwipe_removed_normal['transactionAmount'].sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of transactions for multi Swipe transactions after excluding the normal ones is: 6014
# average transaction amount for multi Swipe transactions after excluding the normal ones is: 146.62727801795785
# total transaction amount for multi Swipe transactions after excluding the normal ones is: 881816.45
# </div>

# %% [markdown]
# ### Question 3-3: anything interesting about either kind of transaction

# %%
df['multiSwipe'] = (df.sort_values(['transactionDateTime'])
                       .groupby(['customerId', 'transactionAmount'], sort=False)['transactionDateTime']
                       .diff()
                       .dt.total_seconds()
                       .lt(120))
ax = sns.countplot(data=df, x='multiSwipe', hue='isFraud')
for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 6700
            value = p.get_height()
            ax.text(_x, _y, value, ha="center", fontsize=14)
plt.xlabel('multi Swipe')
df['multiSwipe'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[123]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">False    777481
# True       8882
# Name: multiSwipe, dtype: int64</div>

# %%
v1 = df['isFraud']
v2 = df['multiSwipe']
v3 = df['followedReversal']

print('significance test for multiSwipe:', ttest_ind(v1, v2))
print('significance test for followedReversal:', ttest_ind(v1, v3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">significance test for multiSwipe: Ttest_indResult(statistic=24.392287496093786, pvalue=2.1847861049414935e-131)
# significance test for followedReversal: Ttest_indResult(statistic=-44.0842381443191, pvalue=0.0)
# </div>

# %%
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[125]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accountNumber</th>
#       <th>customerId</th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionDateTime</th>
#       <th>transactionAmount</th>
#       <th>merchantName</th>
#       <th>acqCountry</th>
# ...

# %%
# import statsmodels.api as sa
# import statsmodels.formula.api as sfa
# lm = sfa.ols(creditLimit ~ isFraud, data=df).fit()
# anova = sa.stats.anova_lm(lm)
# print(anova)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Question 4: Model
# Fraud is a problem for any bank. Fraud can take many forms, whether it is someone stealing a single credit card, to large batches of stolen credit card numbers being used on the web, or even a mass compromise of credit card numbers stolen from a merchant via tools like credit card skimming devices.

# Each of the transactions in the dataset has a field called isFraud. Please build a predictive model to determine whether a given transaction will be fraudulent or not. Use as much of the data as you like (or all of it).

# Provide an estimate of performance using an appropriate sample, and show your work.

# Please explain your methodology (modeling algorithm/method used and why, what features/data you found useful, what questions you have, and what you would do next with more time)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Question 4-1: build a predictive model

# %%
df.head(5)
# df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[128]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>accountNumber</th>
#       <th>customerId</th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionDateTime</th>
#       <th>transactionAmount</th>
#       <th>merchantName</th>
#       <th>acqCountry</th>
# ...

# %%
#remove the duplicate rows 
df['duplicated']  = np.where(
   (df.followedReversal == 1) | (df.multiSwipe == 'True'), 1,0)
df['duplicated'].value_counts()
df['duplicated'] = np.where(df['duplicated'] == 0, 'Not Duplicated', 'Duplicated')
df['duplicated'].value_counts()
df = df[df['duplicated'] != 'Duplicated']
df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[129]: (766060, 33)</div>

# %%
df['recurringAuthInd'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[130]:     766060
# Name: recurringAuthInd, dtype: int64</div>

# %%
for col in ['cardPresent', 'sameCVV', 'expirationDateKeyInMatch','isFraud']:
    df[col] = df[col].replace({False: 0, True: 1})

df.drop(['echoBuffer',
         'cardLast4Digits',
         'merchantName',
         'accountOpenDate',
         'transactionDateTime',
         'currentExpDate',
         'customerId',
         'dateOfLastAddressChange',
         'accountNumber',
         'enteredCVV', 'duplicated', 
         'cardCVV', 'merchantCity', 'merchantState', 'merchantZip', 'posOnPremises', 'recurringAuthInd',
         ], inplace=True, axis=1)
df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[131]: (766060, 16)</div>

# %%
# df.drop([ 'merchantCity', 'merchantState', 'merchantZip',
#          ], inplace=True, axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[133]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionAmount</th>
#       <th>acqCountry</th>
#       <th>merchantCountryCode</th>
#       <th>posEntryMode</th>
#       <th>posConditionCode</th>
# ...

# %%
df[:] = np.nan_to_num(df)
df = df.fillna(df.median())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.under_sampling import RandomUnderSampler
  
numeric_features = ['creditLimit',	'availableMoney', 'transactionAmount', 'currentBalance','cardPresent', 'expirationDateKeyInMatch', 'sameCVV',	'followedReversal', 'multiSwipe']
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]
)

categorical_features = ['acqCountry','merchantCountryCode', 'posEntryMode',	'posConditionCode',	'merchantCategoryCode',	'transactionType']
categorical_transformer =  Pipeline(steps=[("imputer", SimpleImputer(strategy='most_frequent')), ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", LogisticRegression())]
)

from sklearn.model_selection import train_test_split 
df1=df
df1=df1[['acqCountry','merchantCountryCode', 'posEntryMode','posConditionCode',	'merchantCategoryCode',	'transactionType', 'creditLimit',	'availableMoney', 'transactionAmount', 'currentBalance','cardPresent', 'expirationDateKeyInMatch', 'sameCVV',	'followedReversal', 'multiSwipe', "isFraud"]]
X = df1.drop('isFraud', axis=1)
y = df1['isFraud']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1234)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_test, y_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">model score: 0.984
# </div>

# %%
from sklearn import set_config
set_config(display='diagram')
clf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[136]: </div>
# ...

# %%
df = pd.get_dummies(df)
df.head(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[137]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionAmount</th>
#       <th>currentBalance</th>
#       <th>cardPresent</th>
#       <th>expirationDateKeyInMatch</th>
#       <th>isFraud</th>
#       <th>sameCVV</th>
# ...

# %%
df.shape
# df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[138]: (766060, 52)</div>

# %%
from imblearn.under_sampling import RandomUnderSampler
ros = RandomUnderSampler()
y = df['isFraud']
df.drop('isFraud', inplace=True, axis=1)
new_X, new_y = ros.fit_resample(df, y)
print(f'Before Random Under Sampling: {df.shape}')
print(f'After Random Under Sampling: {new_X.shape}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Before Random Under Sampling: (766060, 51)
# After Random Under Sampling: (24160, 51)
# </div>

# %%
from sklearn.model_selection import train_test_split 
# X = df.drop(['isFraud'], axis=1).values
# y = df['isFraud'].values
X_train, X_test, y_train, y_test = train_test_split(new_X, new_y, random_state = 1234)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[141]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>creditLimit</th>
#       <th>availableMoney</th>
#       <th>transactionAmount</th>
#       <th>currentBalance</th>
#       <th>cardPresent</th>
#       <th>expirationDateKeyInMatch</th>
#       <th>sameCVV</th>
# ...

# %%
df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[142]: creditLimit                                  0
# availableMoney                               0
# transactionAmount                            0
# currentBalance                               0
# cardPresent                                  0
# expirationDateKeyInMatch                     0
# sameCVV                                      0
# followedReversal                             0
# multiSwipe                                   0
# acqCountry_                                  0
# acqCountry_CAN                               0
# acqCountry_MEX                               0
# ...

# %%
# df['creditLimit'] = df['creditLimit'].apply(pd.to_numeric)
# df['availableMoney'] = df['availableMoney'].apply(pd.to_numeric)
# df['transactionAmount'] = df['transactionAmount'].apply(pd.to_numeric)
# df['currentBalance'] = df['currentBalance'].apply(pd.to_numeric)
# df[	'cardPresent'] = df['cardPresent'].apply(pd.to_numeric)
# df['expirationDateKeyInMatch'] = df['expirationDateKeyInMatch'].apply(pd.to_numeric)
# df['sameCVV'] = df['sameCVV'].apply(pd.to_numeric)
# df['followedReversal'] = df['followedReversal'].apply(pd.to_numeric)
# df['multiSwipe'] = df['multiSwipe'].apply(pd.to_numeric)
# df['isFraud'] = df['isFraud'].apply(pd.to_numeric)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(df.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(766060, 51)
# </div>

# %%
import xgboost as xgb 
import sklearn
model = xgb.XGBClassifier()
cls= model.fit(X_train, y_train)
sklearn.metrics.plot_confusion_matrix(cls, X_test, y_test, normalize = 'true'); plt.title('Confusion Matrix for XGBClassifier')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[19:59:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective &#39;binary:logistic&#39; was changed from &#39;error&#39; to &#39;logloss&#39;. Explicitly set eval_metric if you&#39;d like to restore the old behavior.
# Out[150]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
# Import required libraries for performance metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_validate

# Define dictionary with performance metrics
scoring = {'accuracy':make_scorer(accuracy_score), 
           'precision':make_scorer(precision_score),
           'recall':make_scorer(recall_score), 
           'f1_score':make_scorer(f1_score)}

# Import required libraries for machine learning classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb
from sklearn.neural_network import MLPClassifier

# Instantiate the machine learning classifiers
log_model = LogisticRegression(max_iter=10000)
svc_model = LinearSVC(dual=False)
dtr_model = DecisionTreeClassifier(random_state=1234)
rfc_model = RandomForestClassifier(random_state=1234)
gnb_model = GaussianNB()
xgb_model = xgb.XGBClassifier()
mlp_model = MLPClassifier(batch_size=10, solver='adam', alpha=1e-5, hidden_layer_sizes=(8, 5), max_iter = 3000, random_state=1)

# Define the models evaluation function
def models_evaluation(X, y, folds):
    
    '''
    X : data set features
    y : data set target
    folds : number of cross-validation folds
    
    '''
    
    # Perform cross-validation to each machine learning classifier
    log = cross_validate(log_model, new_X, new_y, cv=folds, scoring=scoring)
    svc = cross_validate(svc_model, new_X, new_y, cv=folds, scoring=scoring)
    dtr = cross_validate(dtr_model, new_X, new_y, cv=folds, scoring=scoring)
    rfc = cross_validate(rfc_model, new_X, new_y, cv=folds, scoring=scoring)
    gnb = cross_validate(gnb_model, new_X, new_y, cv=folds, scoring=scoring)
    xgb = cross_validate(xgb_model, new_X, new_y, cv=folds, scoring=scoring)
    mlp = cross_validate(mlp_model, new_X, new_y, cv=folds, scoring=scoring)
    

    # Create a data frame with the models perfoamnce metrics scores
    models_scores_table = pd.DataFrame({'Logistic Regression':[log['test_accuracy'].mean(),
                                                               log['test_precision'].mean(),
                                                               log['test_recall'].mean(),
                                                               log['test_f1_score'].mean()],
                                       
                                      'Support Vector Classifier':[svc['test_accuracy'].mean(),
                                                                   svc['test_precision'].mean(),
                                                                   svc['test_recall'].mean(),
                                                                   svc['test_f1_score'].mean()],
                                       
                                      'Decision Tree':[dtr['test_accuracy'].mean(),
                                                       dtr['test_precision'].mean(),
                                                       dtr['test_recall'].mean(),
                                                       dtr['test_f1_score'].mean()],
                                       
                                      'Random Forest':[rfc['test_accuracy'].mean(),
                                                       rfc['test_precision'].mean(),
                                                       rfc['test_recall'].mean(),
                                                       rfc['test_f1_score'].mean()],
                                       
                                      'Gaussian Naive Bayes':[gnb['test_accuracy'].mean(),
                                                              gnb['test_precision'].mean(),
                                                              gnb['test_recall'].mean(),
                                                              gnb['test_f1_score'].mean()],
                                       
                                       'EX Gradient Boost':[xgb['test_accuracy'].mean(),
                                                       xgb['test_precision'].mean(),
                                                       xgb['test_recall'].mean(),
                                                       xgb['test_f1_score'].mean()],
                                       
                                      'MultiLayer Percepton':[mlp['test_accuracy'].mean(),
                                                              mlp['test_precision'].mean(),
                                                              mlp['test_recall'].mean(),
                                                              mlp['test_f1_score'].mean()]},                                    
                                      index=['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    
    # Add 'Best Score' column
    models_scores_table['Best Score'] = models_scores_table.idxmax(axis=1)
    
    # Return models performance metrics scores data frame
    return(models_scores_table)
  
# Run models_evaluation function
models_evaluation(new_X, new_y, 5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[20:02:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective &#39;binary:logistic&#39; was changed from &#39;error&#39; to &#39;logloss&#39;. Explicitly set eval_metric if you&#39;d like to restore the old behavior.
# [20:02:13] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective &#39;binary:logistic&#39; was changed from &#39;error&#39; to &#39;logloss&#39;. Explicitly set eval_metric if you&#39;d like to restore the old behavior.
# ...

# %%
# Metrics being used
from sklearn.metrics import accuracy_score, \
    confusion_matrix, \
    roc_curve
# Plot generating functions to not rewrite code

def plot_confusion(y_pred, y_true):
    conf = confusion_matrix(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    print()
    print(f'Accuracy: {acc}')
    sns.heatmap(conf,
                cmap='Blues',
                cbar=False,
                annot=True,
                fmt='g',
                xticklabels=['False', 'True'],
                yticklabels=['False', 'True'],
                annot_kws={"size": 20}
                )
    plt.show()

def plot_roc(models):
    for key, value in models.items():
        fpr, tpr, _ = roc_curve(value[0], value[1])
        sns.lineplot(x=fpr, y=tpr, label=key)

    ax = sns.lineplot(x=[0, 0.5, 1], y=[0, 0.5, 1])
    ax.lines[len(models)].set_linestyle("--")
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.ensemble import GradientBoostingClassifier
import sklearn.metrics as metrics

plt.figure()


# Add the models to the list that you want to view on the ROC plot
models = [
{
    'label': 'Logistic Regression',
    'model': LogisticRegression(),
},
{
    'label': 'Gradient Boosting',
    'model': GradientBoostingClassifier(),
},
{
    'label': 'Random Forest',
    'model': RandomForestClassifier(),
},
{
    'label': 'DecisionTree Classifier',
    'model': DecisionTreeClassifier(),
},
{
    'label': 'Multi Layer Percepton',
    'model': MLPClassifier(batch_size=10, solver='adam', alpha=1e-5, hidden_layer_sizes=(150, 100, 50), max_iter = 1000, random_state=1),
}
]

# Below for loop iterates through your models list
for m in models:
    model = m['model'] # select the model
    model.fit(X_train, y_train) # train the model
    y_pred=model.predict(X_test) # predict the test data
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = metrics.roc_curve(y_test, model.predict_proba(X_test)[:,1])
# Calculate Area under the curve to display on the plot
    auc = metrics.roc_auc_score(y_test,model.predict(X_test))
# Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['label'], auc))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()   # Display

# %% [markdown]
# #### Question 4-2: Please explain your methodology (modeling algorithm/method used and why, what features/data you found useful, what questions you have, and what you would do next with more time)

# %% [markdown]
# ####
# After exploring the dataset and understanding it, in terms of number of record and number of variables, I checked the missing values. Each column was checked for any missing values and a few variables that were fully blank were removed. Then, I tested a few hypotheses that whether
# the target variable 'isFruad' and some other variables follow a normal distribution. Normality test was conducted, and I found out that neither of those variables follow a normal distribution and most of them are rightly skewed. Then, I checked to see if there are any statistically significance variables with the target variable and I found out that there are, and results were shown visually too. I found the fraud account with largest transaction and top merchants associated with that.
# Then, a few variables were created to identify whether a purchase is followed by a reversal or if there were multiple swipes, and based on these two factors, another variable was created to show whether a transaction is duplicated or not. I got the number of transactions and their amounts of those duplicated ones when the first transaction of each group was included and excluded.
# Next, I created a pipeline for data preprocessing. This pipeline was defined to impute the missing values of numerical fields with their median and categorical fields with their most frequent level. In addition, one hot encoding for categorical variables and standard scaling for numerical variables were also included within the pipeline.
# After, preprocessing the data, I fitted the data into a logistic regression model and checked the accuracy, false positive and true negative rate. As expected, the accuracy was high (around 0.98) but false negative rate was almost 1. Because the data was extremely skewed toward right, I had this initial expectation that the model will fail to correctly predict those transactions that were actually fraud.
# To overcome this issue, I used under sampling technique to lower the number of major classes (False) in order to create a balance between the frequency of both classes of the target variable.
# Next, I fitted the data into several classification models as Logistic Regression, Support Vector Classifier, Decision Tree, Random Forest, Gaussian Naive Bayes, EX Gradient Boost	and Multilayer Perceptron and compared their performances based on the achieved area under curve and F1 score.
# Based on this comparison, Gradient Boosting Classifier outperformed the other models. I checked both the test scores and validation scores, and found them very similar, so it does not seem like there is any under-fitting or over-fitting. XGBClassifier achieved True Positive and True Negative Rates of 0.69 and 0.7. It also obtained False Positive and False Negative Rates of 0.31 and 0.30 respectively.
# If I had more time, I would do some feature engineering work to manage the feature space better and then at the modeling stage, I would try to tune the parameters of the winning model to achieve higher scores. I would also try under methods like modifying the cost function to penalize missing the minor class or over sampling technique to see if I could get better results.
